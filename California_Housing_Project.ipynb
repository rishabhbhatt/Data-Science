# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhbhatt/Data-Science/blob/main/California_Housing_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **California Housing Project**

# %% [markdown]
# **First write a short summary of this data :**
#
# We are given a dataset of housing in california. The California state in this dataset is divided into different regions, which are
#  1. Near Bay,
#  2. Less than 1 hr drvive for ocean,
#  3. Inland Area,
#  4. Near Ocean,
#  5. Island.
#
# and this dataset showcases factors like Location as longitude	and latitude,	housing median age,	total rooms,	total bedrooms,	population,	households,	median_income,	median house value,	ocean proximity   for these regions in california.

# %% [markdown]
# **1. What is the average median income of the data set and check the distribution of data using appropriate plots. Please explain the distribution of the plot.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/housing+(1).xlsx')
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
# 5    -122.25     37.85                  52          919           213.0
# 6    -122.25     37.84                  52         2535           489.0
# 7    -122.25     37.84                  52         3104           687.0
# 8    -122.26     37.84                  42         2555           665.0
# 9    -122.25     37.84                  52         3549           707.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# ...

# %%
# By this we get to know the details of the data like shape gives us number of rows and columns info gives us every details of the column and in our case it shows null values
print(df.shape)
print(df.info())
# Out:
# (20640, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB
# None

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
#By this we can see the distribution of regions in california like how many people resides where?
sns.countplot(data=df, x='ocean_proximity')
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='count'>

# %%
avg=df['median_income'].mean()
avg
# Out:
# 3.8706710029069766

# %%
Avg_in_dollars = avg * 1000
Avg_in_dollars
# Out:
# 3870.671002906977

# %%
plt.hist(df.median_income, color= 'yellow', edgecolor= 'black', bins=20)
plt.title('Distribution of Median income for Housing in california')
plt.ylabel('frequency')
plt.xlabel('median income')
plt.show()

# %% [markdown]
# **2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.**

# %%
sns.boxplot(data=df, x='housing_median_age',color='green')
plt.title('Distribution of Housing median age')
plt.xlabel('Housing Median Age')
plt.ylabel('freq')
plt.show()

# %% [markdown]
# **3. Show with the help of visualization, how median_income and median_house_values are related?**

# %%
#Here we have plotted 2 columns as a scatter plot and grouped it with ocean proximity column to give us betterunderstanding of where are these people residing.
#hue= ocean proxi... gives use detail info of distributed data
sns.scatterplot(data=df, x='median_house_value', y='median_income', s=15,  hue='ocean_proximity')
# Out:
# <Axes: xlabel='median_house_value', ylabel='median_income'>

# %% [markdown]
# Here we can say:
# 1. [Green] Inland- cheaper houses as compared to thers which is between 1-200k
# 2. [Orange] Less than 1 hr ride for Ocean - It has houses which values both from lower end to higher end range from 150k-450k which is very much diversified.
# 3. [Blue] Near Bay - It has few houses in every range starts from 100k - 500k
# 4. [Red] Near Ocean - It has houses in range of 100k to 500k
# 5. [purple] Island - People dont prefer Island as it has no sufficient data to be visible
# --------------
# Also, Here we can observe the cluster near 500k we get to know that irrespective of income people prefer to buy houses which values 500k or more.
#
# Also, If we compare housing value and people with median income here we get to know that Houses that are <1H drive away from Ocean are more expensive from the houses in Inland

# %% [markdown]
# **4. Create a data set by deleting the corresponding examples from the data set for which total_bedrooms are not available.**

# %%
#we have to remove rows which has null values in 'total_bedrooms' column
#by isna and sum we get the total sum of null values in the dataset, and then we can determine what to do further with the null values
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %%
d1=df.dropna()
d1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#we can differentiate here like how many rows and columns were there before and after deleting rows in 'total_bedrooms' column consisting null values
print('Before')
print(df.shape)
print('------------')
print('After')
print(d1.shape)
# Out:
# Before
# (20640, 10)
# ------------
# After
# (20433, 10)

# %% [markdown]
# **5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.**

# %%
#Here we have to fill the null values with the mean value of other rows in the 'total_bedrooms' column
tam=df.fillna(value=df['total_bedrooms'].mean())

# %%
print('[Before] when null values were deleted')
print(d1.shape)
print('------------')
print('[After] adding mean values to the null values')
print(tam.shape )
# Out:
# [Before] when null values were deleted
# (20433, 10)
# ------------
# [After] adding mean values to the null values
# (20640, 10)

# %% [markdown]
# **6. Write a programming construct (create a user defined function) to calculate the median value of the data set wherever required.**

# %%
def median_value(data):
  print(data.median())

median_value(df['longitude'])
median_value(df['latitude'])
median_value(df['housing_median_age'])
median_value(df['total_rooms'])
median_value(df['total_bedrooms'])
median_value(df['population'])
median_value(df['households'])
median_value(df['median_income'])
median_value(df['median_house_value'])
# Out:
# -118.49
# 34.26
# 29.0
# 2127.0
# 435.0
# 1166.0
# 409.0
# 3.5347999999999997
# 179700.0

# %% [markdown]
# **7. Plot latitude versus longitude and explain your observations.**

# %%
sns.scatterplot(data=df, x='latitude',  y='longitude', marker='H' , hue='ocean_proximity')
plt.title('Latitude VS Longitude')
plt.ylabel('Longitude')
plt.xlabel('Latitude')
plt.show()

# %% [markdown]
# **8. Create a data set for which the ocean_proximity is ‘Near ocean’.**

# %%
#So here we have printed every row which contains ocean_proximity = NEAR OCEAN
df.head()

data_new = df.loc[df['ocean_proximity']== 'NEAR OCEAN']
data_new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %% [markdown]
# **9. Find the mean and median of the median income for the data set created in question 8.**

# %%
data_new['median_income'].mean()
# Out:
# 4.0057848006019565

# %%
data_new['median_income'].median()
# Out:
# 3.64705

# %% [markdown]
# **10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less, it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.**

# %%
import numpy as np
cond = [
         (df['total_bedrooms'] <= 10 ),
         (df['total_bedrooms'] >= 11 ) &
         (df['total_bedrooms'] <=1000 ),
         (df['total_bedrooms'] > 1000 )
       ]

values = ['small','medium','large']


df['total_bedroom_size'] = np.select(cond, values)

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
